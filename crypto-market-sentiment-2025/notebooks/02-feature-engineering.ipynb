# %% [markdown]
# # Feature Engineering for Cryptocurrency Market Sentiment & Price Data 2025
#
# In this notebook, we will explore various feature engineering techniques to enhance the performance of our models predicting cryptocurrency prices based on market sentiment and price data. The goal is to create meaningful features that can improve the predictive power of our machine learning models.

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the dataset
data = pd.read_csv('../../Dataset/crypto_sentiment_prediction_dataset.csv')
data.head()
# Out:
#              timestamp cryptocurrency  current_price_usd  \
# 0  2025-06-04 20:36:49       Algorand             0.3427
# 1  2025-06-04 20:48:25         Cosmos            12.0420
# 2  2025-06-04 21:28:54         Cosmos            11.7675
# 3  2025-06-04 21:57:48       Ethereum          2861.2829
# 4  2025-06-04 22:06:40         Solana            95.3583
#
#    price_change_24h_percent  trading_volume_24h  market_cap_usd  \
# 0                     -5.35          1716266.10    1.762124e+09
# 1                      5.14         10520739.91    2.099178e+11
# 2                     -6.12           642191.11    1.755367e+11
# 3                    -11.54          5356227.76    4.786419e+13
# 4                      5.79           735971.56    2.667611e+11
#
#    social_sentiment_score  news_sentiment_score  news_impact_score  \
# 0                   0.367                 0.374               1.87
# 1                  -0.278                -0.107               1.01
# 2                  -0.255                 0.211               5.69
# 3                  -0.531                -0.081               5.11
# 4                   0.369                 0.248               1.82
#
#    social_mentions_count  fear_greed_index  volatility_index  \
# 0                     13              53.2              95.1
# 1                    600              43.5              76.7
# 2                    279              49.1              60.4
# 3                   3504              37.0             100.0
# 4                   3236              61.7              67.5
#
#    rsi_technical_indicator  prediction_confidence
# 0                     37.2                   78.1
# 1                     65.0                   66.7
# 2                     32.3                   77.4
# 3                     63.0                   81.7
# 4                     55.4                   81.8

# %% [markdown]
# ## 1. Handling Missing Values
#
# Before feature engineering, we need to address any missing values in the dataset. This can be done through various methods such as imputation or removal.

# %%
# Check for missing values
missing_values = data.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## 2. Feature Creation
#
# We will create new features that may help in predicting cryptocurrency prices. This includes:
# - **Lag Features**: Previous values of the target variable.
# - **Rolling Statistics**: Moving averages and standard deviations.
# - **Sentiment Scores**: Aggregate sentiment scores from textual data.

# %%
# Create lag features
for lag in range(1, 4):
    data[f'price_lag_{lag}'] = data['current_price_usd'].shift(lag)

# Create rolling features
data['rolling_mean'] = data['current_price_usd'].rolling(window=3).mean()
data['rolling_std'] = data['current_price_usd'].rolling(window=3).std()

# Display the new features
data[['current_price_usd', 'price_lag_1', 'price_lag_2', 'price_lag_3', 'rolling_mean', 'rolling_std']].head()
# Out:
#    current_price_usd  price_lag_1  price_lag_2  price_lag_3  rolling_mean  \
# 0             0.3427          NaN          NaN          NaN           NaN
# 1            12.0420       0.3427          NaN          NaN           NaN
# 2            11.7675      12.0420       0.3427          NaN      8.050733
# 3          2861.2829      11.7675      12.0420       0.3427    961.697467
# 4            95.3583    2861.2829      11.7675      12.0420    989.469567
#
#    rolling_std
# 0          NaN
# 1          NaN
# 2     6.676764
# 3  1645.089248
# 4  1621.576616

# %% [markdown]
# ## 3. Encoding Categorical Variables
#
# If there are any categorical variables, we will encode them using techniques such as one-hot encoding or label encoding.

# %%
# Identify categorical columns
categorical_cols = data.select_dtypes(include=['object']).columns.tolist()

# One-hot encode categorical variables
data = pd.get_dummies(data, columns=categorical_cols, drop_first=True)
data.head()
# Out:
#    current_price_usd  price_change_24h_percent  trading_volume_24h  \
# 0             0.3427                     -5.35          1716266.10
# 1            12.0420                      5.14         10520739.91
# 2            11.7675                     -6.12           642191.11
# 3          2861.2829                    -11.54          5356227.76
# 4            95.3583                      5.79           735971.56
#
#    market_cap_usd  social_sentiment_score  news_sentiment_score  \
# 0    1.762124e+09                   0.367                 0.374
# 1    2.099178e+11                  -0.278                -0.107
# 2    1.755367e+11                  -0.255                 0.211
# 3    4.786419e+13                  -0.531                -0.081
# 4    2.667611e+11                   0.369                 0.248
#
#    news_impact_score  social_mentions_count  fear_greed_index  \
# 0               1.87                     13              53.2
# 1               1.01                    600              43.5
# 2               5.69                    279              49.1
# 3               5.11                   3504              37.0
# 4               1.82                   3236              61.7
#
#    volatility_index  ...  timestamp_2025-07-04 19:58:28  \
# 0              95.1  ...                          False
# 1              76.7  ...                          False
# 2              60.4  ...                          False
# 3             100.0  ...                          False
# 4              67.5  ...                          False
#
#    cryptocurrency_Avalanche  cryptocurrency_Bitcoin  cryptocurrency_Cardano  \
# 0                     False                   False                   False
# 1                     False                   False                   False
# 2                     False                   False                   False
# 3                     False                   False                   False
# 4                     False                   False                   False
#
#    cryptocurrency_Chainlink  cryptocurrency_Cosmos  cryptocurrency_Ethereum  \
# 0                     False                  False                    False
# 1                     False                   True                    False
# 2                     False                   True                    False
# 3                     False                  False                     True
# 4                     False                  False                    False
#
#    cryptocurrency_Polkadot  cryptocurrency_Polygon  cryptocurrency_Solana
# 0                    False                   False                  False
# 1                    False                   False                  False
# 2                    False                   False                  False
# 3                    False                   False                  False
# 4                    False                   False                   True
#
# [5 rows x 2088 columns]

# %% [markdown]
# ## 4. Scaling Numerical Features
#
# We will scale the numerical features to ensure they are on a similar scale, which can improve model performance.

# %%
# Scale numerical features
scaler = StandardScaler()
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns.tolist()
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])
data.head()
# Out:
#    current_price_usd  price_change_24h_percent  trading_volume_24h  \
# 0          -0.338078                 -0.666587           -0.560222
# 1          -0.337149                  0.644844            0.621688
# 2          -0.337171                 -0.762850           -0.704406
# 3          -0.111032                 -1.440443           -0.071595
# 4          -0.330537                  0.726105           -0.691817
#
#    market_cap_usd  social_sentiment_score  news_sentiment_score  \
# 0       -0.288936                1.173421              1.203785
# 1       -0.287619               -0.953525             -0.354293
# 2       -0.287837               -0.877680              0.675788
# 3        0.013782               -1.787815             -0.270073
# 4       -0.287260                1.180016              0.795640
#
#    news_impact_score  social_mentions_count  fear_greed_index  \
# 0          -1.062343              -0.482004          0.202417
# 1          -1.564780              -0.247264         -0.523417
# 2           1.169413              -0.375631         -0.104379
# 3           0.830560               0.914039         -1.009801
# 4          -1.091554               0.806867          0.838458
#
#    volatility_index  ...  timestamp_2025-07-04 19:58:28  \
# 0          0.878650  ...                          False
# 1          0.012385  ...                          False
# 2         -0.755013  ...                          False
# 3          1.109340  ...                          False
# 4         -0.420748  ...                          False
#
#    cryptocurrency_Avalanche  cryptocurrency_Bitcoin  cryptocurrency_Cardano  \
# 0                     False                   False                   False
# 1                     False                   False                   False
# 2                     False                   False                   False
# 3                     False                   False                   False
# 4                     False                   False                   False
#
#    cryptocurrency_Chainlink  cryptocurrency_Cosmos  cryptocurrency_Ethereum  \
# 0                     False                  False                    False
# 1                     False                   True                    False
# 2                     False                   True                    False
# 3                     False                  False                     True
# 4                     False                  False                    False
#
#    cryptocurrency_Polkadot  cryptocurrency_Polygon  cryptocurrency_Solana
# 0                    False                   False                  False
# 1                    False                   False                  False
# 2                    False                   False                  False
# 3                    False                   False                  False
# 4                    False                   False                   True
#
# [5 rows x 2088 columns]

# %% [markdown]
# ## 5. Finalizing the Feature Set
#
# After feature engineering, we will finalize the feature set to be used for modeling. This includes selecting the target variable and the features.

# %%
# Define target and features
X = data.drop(columns=['current_price_usd'])  # Features
y = data['current_price_usd']  # Target variable

# Display the final feature set
X.head()
# Out:
#    price_change_24h_percent  trading_volume_24h  market_cap_usd  \
# 0                 -0.666587           -0.560222       -0.288936
# 1                  0.644844            0.621688       -0.287619
# 2                 -0.762850           -0.704406       -0.287837
# 3                 -1.440443           -0.071595        0.013782
# 4                  0.726105           -0.691817       -0.287260
#
#    social_sentiment_score  news_sentiment_score  news_impact_score  \
# 0                1.173421              1.203785          -1.062343
# 1               -0.953525             -0.354293          -1.564780
# 2               -0.877680              0.675788           1.169413
# 3               -1.787815             -0.270073           0.830560
# 4                1.180016              0.795640          -1.091554
#
#    social_mentions_count  fear_greed_index  volatility_index  \
# 0              -0.482004          0.202417          0.878650
# 1              -0.247264         -0.523417          0.012385
# 2              -0.375631         -0.104379         -0.755013
# 3               0.914039         -1.009801          1.109340
# 4               0.806867          0.838458         -0.420748
#
#    rsi_technical_indicator  ...  timestamp_2025-07-04 19:58:28  \
# 0                -0.880145  ...                          False
# 1                 0.959349  ...                          False
# 2                -1.204372  ...                          False
# 3                 0.827011  ...                          False
# 4                 0.324128  ...                          False
#
#    cryptocurrency_Avalanche  cryptocurrency_Bitcoin  cryptocurrency_Cardano  \
# 0                     False                   False                   False
# 1                     False                   False                   False
# 2                     False                   False                   False
# 3                     False                   False                   False
# 4                     False                   False                   False
#
#    cryptocurrency_Chainlink  cryptocurrency_Cosmos  cryptocurrency_Ethereum  \
# 0                     False                  False                    False
# 1                     False                   True                    False
# 2                     False                   True                    False
# 3                     False                  False                     True
# 4                     False                  False                    False
#
#    cryptocurrency_Polkadot  cryptocurrency_Polygon  cryptocurrency_Solana
# 0                    False                   False                  False
# 1                    False                   False                  False
# 2                    False                   False                  False
# 3                    False                   False                  False
# 4                    False                   False                   True
#
# [5 rows x 2087 columns]

# %% [markdown]
# ## Conclusion
#
# In this notebook, we have performed feature engineering on the Cryptocurrency Market Sentiment & Price Data 2025 dataset. We created new features, handled missing values, encoded categorical variables, and scaled numerical features. The next steps will involve model training and evaluation using the engineered features.
