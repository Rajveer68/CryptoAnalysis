# %% [markdown]
# # Exploratory Data Analysis (EDA) on Cryptocurrency Market Sentiment & Price Data 2025
#
# This notebook is dedicated to performing exploratory data analysis on the Cryptocurrency Market Sentiment & Price Data 2025 dataset. The goal is to uncover insights, visualize trends, and prepare the data for further analysis.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set(style='whitegrid')

# %% [markdown]
# ## Load the Dataset
#
# In this section, we will load the dataset and take a look at its structure.

# %%
# Load the dataset
data = pd.read_csv('../../Dataset/crypto_sentiment_prediction_dataset.csv')

# Display the shape of the dataset
data.shape
# Out:
# (2063, 14)

# %% [markdown]
# ## Data Overview
#
# Let's take a look at the first few rows of the dataset to understand its structure and the types of data it contains.

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#              timestamp cryptocurrency  current_price_usd  \
# 0  2025-06-04 20:36:49       Algorand             0.3427
# 1  2025-06-04 20:48:25         Cosmos            12.0420
# 2  2025-06-04 21:28:54         Cosmos            11.7675
# 3  2025-06-04 21:57:48       Ethereum          2861.2829
# 4  2025-06-04 22:06:40         Solana            95.3583
#
#    price_change_24h_percent  trading_volume_24h  market_cap_usd  \
# 0                     -5.35          1716266.10    1.762124e+09
# 1                      5.14         10520739.91    2.099178e+11
# 2                     -6.12           642191.11    1.755367e+11
# 3                    -11.54          5356227.76    4.786419e+13
# 4                      5.79           735971.56    2.667611e+11
#
#    social_sentiment_score  news_sentiment_score  news_impact_score  \
# 0                   0.367                 0.374               1.87
# 1                  -0.278                -0.107               1.01
# 2                  -0.255                 0.211               5.69
# 3                  -0.531                -0.081               5.11
# 4                   0.369                 0.248               1.82
#
#    social_mentions_count  fear_greed_index  volatility_index  \
# 0                     13              53.2              95.1
# 1                    600              43.5              76.7
# 2                    279              49.1              60.4
# 3                   3504              37.0             100.0
# 4                   3236              61.7              67.5
#
#    rsi_technical_indicator  prediction_confidence
# 0                     37.2                   78.1
# 1                     65.0                   66.7
# 2                     32.3                   77.4
# 3                     63.0                   81.7
# 4                     55.4                   81.8

# %% [markdown]
# ## Data Cleaning
#
# We will check for missing values and perform any necessary data cleaning.

# %%
# Check for missing values
data.isnull().sum()
# Out:
# timestamp                   0
# cryptocurrency              0
# current_price_usd           0
# price_change_24h_percent    0
# trading_volume_24h          0
# market_cap_usd              0
# social_sentiment_score      0
# news_sentiment_score        0
# news_impact_score           0
# social_mentions_count       0
# fear_greed_index            0
# volatility_index            0
# rsi_technical_indicator     0
# prediction_confidence       0
# dtype: int64

# %% [markdown]
# ## Data Visualization
#
# We will create visualizations to explore the relationship between price and sentiment over time.

# %%
# Convert 'timestamp' to datetime format (it's already in datetime format, but ensuring it's parsed correctly)
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Plot Price and Sentiment over Time
plt.figure(figsize=(14, 7))
plt.plot(data['timestamp'], data['current_price_usd'], label='Price', color='blue')
plt.plot(data['timestamp'], data['social_sentiment_score'], label='Social Sentiment', color='orange')
plt.title('Cryptocurrency Price and Social Sentiment Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ## Correlation Analysis
#
# We will analyze the correlation between price and sentiment.

# %%
# Calculate correlation
correlation = data[['current_price_usd', 'social_sentiment_score', 'news_sentiment_score']].corr()
correlation
# Out:
#                         current_price_usd  social_sentiment_score  \
# current_price_usd                1.000000               -0.025443
# social_sentiment_score          -0.025443                1.000000
# news_sentiment_score            -0.065416                0.580926
#
#                         news_sentiment_score
# current_price_usd                  -0.065416
# social_sentiment_score              0.580926
# news_sentiment_score                1.000000

# %% [markdown]
# ## Conclusion
#
# In this exploratory data analysis, we have loaded the dataset, performed data cleaning, visualized the relationship between price and sentiment, and analyzed their correlation. These insights will guide further analysis and feature engineering.
